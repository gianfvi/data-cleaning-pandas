# %%
#pip install xlrd

# %%
import pandas as pd
import csv

# %%
# shows us what were working with
url = "https://www.sharkattackfile.net/spreadsheets/GSAF5.xls"
shark_data =  pd.read_excel(url)  # usecols=["Embarked"]
shark_data.head()
# Out:
#           Date    Year        Type    Country              State  \
# 0  15 Mar 2024  2024.0  Unprovoked  AUSTRALIA         Queensland
# 1  04 Mar 2024  2024.0  Unprovoked        USA             Hawaii
# 2  02 Mar-2024  2024.0  Unprovoked        USA             Hawaii
# 3  25 Feb-2024  2024.0  Unprovoked  AUSTRALIA  Western Australia
# 4  14 Feb-2024  2024.0  Unprovoked      INDIA        Maharashtra
#
#                            Location  Activity                 Name Sex  Age  \
# 0                     Bargara Beach  Swimming       Brooklyn Sauer   F   13
# 1                Old Man's, Waikiki   Surfing        Matthew White   M  NaN
# 2                    Rainbows, Oahu  Swimming                  NaN   F   11
# 3        Sandlnd Island, Jurian Bay       NaN               female   F   46
# 4  Vaitarna River, Palghar District   Fishing  Vicky Suresh Govari   M   32
#
#    ...        Species                      Source  pdf href formula href  \
# 0  ...     Tiger shark      Yahoo News, 3/15/2024  NaN          NaN  NaN
# 1  ...  Tiger shark 8'          Surfer, 3/6/2024F  NaN          NaN  NaN
# 2  ...  3' to 4' shark  Hawaii News Now, 3/4/2024  NaN          NaN  NaN
# 3  ...     Tiger shark        WA Today, 2/26/2024  NaN          NaN  NaN
# 4  ...  Bull shark, 7'  Times of India, 2/14/2024  NaN          NaN  NaN
#
#   Case Number Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0         NaN           NaN            NaN         NaN         NaN
# 1         NaN           NaN            NaN         NaN         NaN
# 2         NaN           NaN            NaN         NaN         NaN
# 3         NaN           NaN            NaN         NaN         NaN
# 4         NaN           NaN            NaN         NaN         NaN
#
# [5 rows x 23 columns]

# %%
# replace all sentence and whitespace from the string date before handling to season
shark_data['Date'] = shark_data['Date'].replace('Before ', '', regex=True)
shark_data['Date'] = shark_data['Date'].replace(' ', '-', regex=True)
# Extract all months ans year from the columns date
shark_data['Month'] = shark_data['Date'].str.extract(r'([a-zA-Z]+)')
shark_data['Year']= shark_data['Date'].str.extract(r'(\d{4})')
# Create a Category for all months
def map_month(month_abbr):
    month_abbr_to_full = {
        'Jan': 'January', 'Feb': 'February', 'Mar': 'March', 'Apr': 'April',
        'May': 'May', 'Jun': 'June', 'Jul': 'July', 'Aug': 'August',
        'Sep': 'September', 'Oct': 'October', 'Nov': 'November', 'Dec': 'December'
    }
    return month_abbr_to_full.get(month_abbr, 'Unknown')
def get_season(month):
    if month in ['December', 'January', 'February']:
        return 'Winter'
    elif month in ['March', 'April', 'May']:
        return 'Spring'
    elif month in ['June', 'July', 'August']:
        return 'Summer'
    elif month in ['September', 'October', 'November']:
        return 'Fall'
    else:
        return 'Unknown'
shark_data['Month'] = shark_data['Month'].apply(map_month)
# Finish the category seasson for the months
shark_data['Season'] = shark_data['Month'].apply(get_season)

# %%
shark_data
# Out:
#              Date  Year        Type    Country              State  \
# 0     15-Mar-2024  2024  Unprovoked  AUSTRALIA         Queensland
# 1     04-Mar-2024  2024  Unprovoked        USA             Hawaii
# 2     02-Mar-2024  2024  Unprovoked        USA             Hawaii
# 3     25-Feb-2024  2024  Unprovoked  AUSTRALIA  Western Australia
# 4     14-Feb-2024  2024  Unprovoked      INDIA        Maharashtra
# ...           ...   ...         ...        ...                ...
# 6964          NaN   NaN         NaN        NaN                NaN
# 6965          NaN   NaN         NaN        NaN                NaN
# 6966          NaN   NaN         NaN        NaN                NaN
# 6967          NaN   NaN         NaN        NaN                NaN
# 6968          NaN   NaN         NaN        NaN                NaN
#
#                               Location  Activity                 Name  Sex  \
# 0                        Bargara Beach  Swimming       Brooklyn Sauer    F
# 1                   Old Man's, Waikiki   Surfing        Matthew White    M
# 2                       Rainbows, Oahu  Swimming                  NaN    F
# 3           Sandlnd Island, Jurian Bay       NaN               female    F
# 4     Vaitarna River, Palghar District   Fishing  Vicky Suresh Govari    M
# ...                                ...       ...                  ...  ...
# 6964                               NaN       NaN                  NaN  NaN
# 6965                               NaN       NaN                  NaN  NaN
# 6966                               NaN       NaN                  NaN  NaN
# 6967                               NaN       NaN                  NaN  NaN
# 6968                               NaN       NaN                  NaN  NaN
#
#       Age  ...  pdf                                       href formula href  \
# 0      13  ...  NaN                                                NaN  NaN
# 1     NaN  ...  NaN                                                NaN  NaN
# 2      11  ...  NaN                                                NaN  NaN
# 3      46  ...  NaN                                                NaN  NaN
# 4      32  ...  NaN                                                NaN  NaN
# ...   ...  ...  ...                                                ...  ...
# 6964  NaN  ...  NaN  http://sharkattackfile.net/spreadsheets/pdf_di...  NaN
# 6965  NaN  ...  NaN  http://sharkattackfile.net/spreadsheets/pdf_di...  NaN
# 6966  NaN  ...  NaN  http://sharkattackfile.net/spreadsheets/pdf_di...  NaN
# 6967  NaN  ...  NaN  http://sharkattackfile.net/spreadsheets/pdf_di...  NaN
# 6968  NaN  ...  NaN  http://sharkattackfile.net/spreadsheets/pdf_di...  NaN
#
#      Case Number Case Number.1 original order Unnamed: 21 Unnamed: 22  \
# 0            NaN           NaN            NaN         NaN         NaN
# 1            NaN           NaN            NaN         NaN         NaN
# 2            NaN           NaN            NaN         NaN         NaN
# 3            NaN           NaN            NaN         NaN         NaN
# 4            NaN           NaN            NaN         NaN         NaN
# ...          ...           ...            ...         ...         ...
# 6964         NaN           NaN            NaN         NaN         NaN
# 6965         NaN           NaN            NaN         NaN         NaN
# 6966         NaN           NaN            NaN         NaN         NaN
# 6967         NaN           NaN            NaN         NaN         NaN
# 6968         NaN           NaN            NaN         NaN         NaN
#
#          Month   Season
# 0        March   Spring
# 1        March   Spring
# 2        March   Spring
# 3     February   Winter
# 4     February   Winter
# ...        ...      ...
# 6964   Unknown  Unknown
# 6965   Unknown  Unknown
# 6966   Unknown  Unknown
# 6967   Unknown  Unknown
# 6968   Unknown  Unknown
#
# [6969 rows x 25 columns]

# %%
url = "https://marineprotectedareas.noaa.gov/media/data/NOAA_Marine_Protected_Areas_Inventory_2023.xlsx"
usa_shark_data =  pd.read_excel(url)  # usecols=["Embarked"]
usa_shark_data.head()
# Out:
#    FID  OBJECTID Site ID                                          Site Name  \
# 0    1         1    AK25                Walrus Islands State Game Sanctuary
# 1    2         2   NPS10                    Cape Hatteras National Seashore
# 2    3         3     AS1                              Ofu Vaoto Marine Park
# 3    4         4     CT1       Bluff Point State Park/Natural Area Preserve
# 4    5         5    CT10  Silver Sands State Park/Charles Island Natural...
#
#   Level of Government State    Level of Protection  \
# 0               State    AK  Zoned w/No Take Areas
# 1             Federal    NC   Uniform Multiple Use
# 2         Territorial   ASM                No Take
# 3               State    CT     Zoned Multiple Use
# 4               State    CT     Zoned Multiple Use
#
#                                    Management Agency  \
# 0                 Alaska Department of Fish and Game
# 1                              National Park Service
# 2    American Samoa Department of Parks & Recreation
# 3  Connecticut Department of Environmental Protec...
# 4  Connecticut Department of Environmental Protec...
#
#                                 Management Plan Primary Conservation Focus  \
# 0  Non-MPA Programmatic Species Management Plan           Natural Heritage
# 1                 Site-Specific Management Plan           Natural Heritage
# 2                            No Management Plan           Natural Heritage
# 3                 Site-Specific Management Plan           Natural Heritage
# 4                            No Management Plan           Natural Heritage
#
#    ... Marine Area (km2) Percent Area Marine No-Take Area (km2)   Longitude  \
# 0  ...        745.460999                  99           0.000000 -160.231047
# 1  ...         28.920485                  23           0.000000  -75.617180
# 2  ...          0.384748                 100           0.384755 -169.670240
# 3  ...          0.112254                   4           0.000000  -72.030288
# 4  ...          0.014841                   1           0.000000  -73.069498
#
#     Latitude  VxCount SHAPE_Leng SHAPE_Area   Shape__Area  Shape__Length
# 0  58.700885     2601   3.298504   0.117017  2.791294e+09  491586.303131
# 1  35.242412     3797   2.741455   0.012495  1.901409e+08  343505.400043
# 2 -14.186982       51   0.025235   0.000032  4.093436e+05    2837.034473
# 3  41.323971      547   0.156012   0.000321  5.292001e+06   19914.004750
# 4  41.202265      863   0.114932   0.000131  2.165473e+06   14112.522816
#
# [5 rows x 37 columns]

# %%
shark_data.isnull()
#values are null wherever it says True
# Out:
#        Date   Year   Type  Country  State  Location  Activity   Name    Sex  \
# 0     False  False  False    False  False     False     False  False  False
# 1     False  False  False    False  False     False     False  False  False
# 2     False  False  False    False  False     False     False   True  False
# 3     False  False  False    False  False     False      True  False  False
# 4     False  False  False    False  False     False     False  False  False
# ...     ...    ...    ...      ...    ...       ...       ...    ...    ...
# 6964   True   True   True     True   True      True      True   True   True
# 6965   True   True   True     True   True      True      True   True   True
# 6966   True   True   True     True   True      True      True   True   True
# 6967   True   True   True     True   True      True      True   True   True
# 6968   True   True   True     True   True      True      True   True   True
#
#         Age  ...   pdf  href formula  href  Case Number  Case Number.1  \
# 0     False  ...  True          True  True         True           True
# 1      True  ...  True          True  True         True           True
# 2     False  ...  True          True  True         True           True
# 3     False  ...  True          True  True         True           True
# 4     False  ...  True          True  True         True           True
# ...     ...  ...   ...           ...   ...          ...            ...
# 6964   True  ...  True         False  True         True           True
# 6965   True  ...  True         False  True         True           True
# 6966   True  ...  True         False  True         True           True
# 6967   True  ...  True         False  True         True           True
# 6968   True  ...  True         False  True         True           True
#
#       original order  Unnamed: 21  Unnamed: 22  Month  Season
# 0               True         True         True  False   False
# 1               True         True         True  False   False
# 2               True         True         True  False   False
# 3               True         True         True  False   False
# 4               True         True         True  False   False
# ...              ...          ...          ...    ...     ...
# 6964            True         True         True  False   False
# 6965            True         True         True  False   False
# 6966            True         True         True  False   False
# 6967            True         True         True  False   False
# 6968            True         True         True  False   False
#
# [6969 rows x 25 columns]

# %%
shark_data.isna().sum()
# Out:
# Date                25
# Year               194
# Type                43
# Country             75
# State              507
# Location           590
# Activity           611
# Name               245
# Sex                604
# Age               3019
# Injury              60
# Unnamed: 11        587
# Time              3551
# Species           3157
# Source              44
# pdf                170
# href formula       150
# href               173
# Case Number        171
# Case Number.1      172
# original order     170
# Unnamed: 21       6968
# Unnamed: 22       6967
# Month                0
# Season               0
# dtype: int64

# %%
shark_data.isna().sum(axis=1)
# Out:
# 0        9
# 1       10
# 2        9
# 3        9
# 4        9
#         ..
# 6964    22
# 6965    22
# 6966    22
# 6967    22
# 6968    22
# Length: 6969, dtype: int64

# %%
shark_data.dropna(thresh=6, inplace=True) # to delete rows with 5 or less empty values

# %%
# drops all unwanted columns and saves the results to a series called shark_data_trimmed
drop_cols = ['pdf', 'href formula', 'href', 'Case Number', 'Case Number.1', 'Species ', 'original order', 'Unnamed: 21', 'Unnamed: 22', 'Source', 'Unnamed: 11', "Name"]
shark_data_trimmed = shark_data.drop( drop_cols, axis=1)

shark_data_trimmed

# Note: think about doing this step before the provoked and unprovoked variables so its based off the trimmed data
# Out:
#              Date  Year        Type             Country              State  \
# 0     15-Mar-2024  2024  Unprovoked           AUSTRALIA         Queensland
# 1     04-Mar-2024  2024  Unprovoked                 USA             Hawaii
# 2     02-Mar-2024  2024  Unprovoked                 USA             Hawaii
# 3     25-Feb-2024  2024  Unprovoked           AUSTRALIA  Western Australia
# 4     14-Feb-2024  2024  Unprovoked               INDIA        Maharashtra
# ...           ...   ...         ...                 ...                ...
# 6939         1903  1903  Unprovoked           AUSTRALIA  Western Australia
# 6940         1903  1903  Unprovoked           AUSTRALIA  Western Australia
# 6941    1900-1905  1900  Unprovoked                 USA     North Carolina
# 6942    1883-1889  1883  Unprovoked              PANAMA                NaN
# 6943    1845-1853  1845  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity Sex  Age  \
# 0                           Bargara Beach      Swimming   F   13
# 1                      Old Man's, Waikiki       Surfing   M  NaN
# 2                          Rainbows, Oahu      Swimming   F   11
# 3              Sandlnd Island, Jurian Bay           NaN   F   46
# 4        Vaitarna River, Palghar District       Fishing   M   32
# ...                                   ...           ...  ..  ...
# 6939                          Roebuck Bay        Diving   M  NaN
# 6940                                  NaN  Pearl diving   M  NaN
# 6941                       Ocracoke Inlet      Swimming   M  NaN
# 6942                 Panama Bay 8ºN, 79ºW           NaN   M  NaN
# 6943  Below the English fort, Trincomalee      Swimming   M   15
#
#                                                  Injury   Time     Month  \
# 0              Minor injuries to back, abdomen and legs  16h00     March
# 1                        No injury, shark bit surfboard    NaN     March
# 2                              Lacerations to left foot  13h30     March
# 3                                            Leg bitten  11h30  February
# 4                        Calf of lower left leg injured    NaN  February
# ...                                                 ...    ...       ...
# 6939                                              FATAL    NaN   Unknown
# 6940                                              FATAL    NaN   Unknown
# 6941                                              FATAL    NaN   Unknown
# 6942                                              FATAL    NaN   Unknown
# 6943  FATAL. "Shark bit him in half, carrying away t...    NaN   Unknown
#
#        Season
# 0      Spring
# 1      Spring
# 2      Spring
# 3      Winter
# 4      Winter
# ...       ...
# 6939  Unknown
# 6940  Unknown
# 6941  Unknown
# 6942  Unknown
# 6943  Unknown
#
# [6944 rows x 13 columns]

# %%
#shark_data.dropna(axis=1) # idk why here

# %%
usa_attack_data = shark_data_trimmed.groupby('Country').get_group('USA')
usa_attack_data
# Out:
#              Date  Year        Type Country            State  \
# 1     04-Mar-2024  2024  Unprovoked     USA           Hawaii
# 2     02-Mar-2024  2024  Unprovoked     USA           Hawaii
# 10    30-Dec-2023  2023  Unprovoked     USA           Hawaii
# 24    05-Nov-2023  2023  Unprovoked     USA          Florida
# 29    25-Oct-2023  2023  Unprovoked     USA           Hawaii
# ...           ...   ...         ...     ...              ...
# 6891         1958  1958  Unprovoked     USA          Florida
# 6925         1921  1921  Unprovoked     USA          Florida
# 6930  17-Jul-1916  1916  Unprovoked     USA  North Carolina
# 6934   Circa-1862  1862  Unprovoked     USA           Hawaii
# 6941    1900-1905  1900  Unprovoked     USA   North Carolina
#
#                                      Location  Activity Sex  Age  \
# 1                          Old Man's, Waikiki   Surfing   M  NaN
# 2                              Rainbows, Oahu  Swimming   F   11
# 10                           Baby Beach, Maui   Surfing   M   39
# 24              Juno Beach, Palm Beach County  Swimming   M   66
# 29              Pua’ena Point,  Haleiwa, Oahu   Surfing   M   30
# ...                                       ...       ...  ..  ...
# 6891            Palm Beach, Palm Beach County  Standing   M  NaN
# 6925                 Gadsden Point, Tampa Bay   Fishing   M  NaN
# 6930  Somewhere between Hatteras and Beaufort  Swimming   M  NaN
# 6934                                     Puna       NaN   F  NaN
# 6941                           Ocracoke Inlet  Swimming   M  NaN
#
#                                 Injury   Time     Month   Season
# 1       No injury, shark bit surfboard    NaN     March   Spring
# 2             Lacerations to left foot  13h30     March   Spring
# 10                               FATAL  11h12  December   Winter
# 24        Lacerations to right forearm  10h30  November     Fall
# 29                 Bite to right thigh  15h05   October     Fall
# ...                                ...    ...       ...      ...
# 6891  Abrasions & bruises hip to ankle    NaN   Unknown  Unknown
# 6925                2-inch lacerations    NaN   Unknown  Unknown
# 6930                        "Lost leg"    NaN      July   Summer
# 6934                      Ankle bitten    NaN   Unknown  Unknown
# 6941                             FATAL    NaN   Unknown  Unknown
#
# [2538 rows x 13 columns]

# %%
# # replace all sentence and whitespace from the string date before handling to season
# shark_data['Date'] = shark_data['Date'].replace('Before ', '', regex=True)
# shark_data['Date'] = shark_data['Date'].replace(' ', '-', regex=True)
# # Extract all months ans year from the columns date
# shark_data['Month'] = shark_data['Date'].str.extract(r'([aA-Z]-z+)')
# shark_data['Year']= shark_data['Date'].str.extract(r'(\d{4})')
# # Create a Category for all months
# def map_month(month_abbr):
#     month_abbr_to_full = {
#         'Jan': 'January', 'Feb': 'February', 'Mar': 'March', 'Apr': 'April',
#         'May': 'May', 'Jun': 'June', 'Jul': 'July', 'Aug': 'August',
#         'Sep': 'September', 'Oct': 'October', 'Nov': 'November', 'Dec': 'December'
#     }
#     return month_abbr_to_full.get(month_abbr, 'Unknown')
# def get_season(month):
#     if month in ['December', 'January', 'February']:
#         return 'Winter'
#     elif month in ['March', 'April', 'May']:
#         return 'Spring'
#     elif month in ['June', 'July', 'August']:
#         return 'Summer'
#     elif month in ['September', 'October', 'November']:
#         return 'Fall'
#     else:
#         return 'Unknown'
# shark_data['Month'] = shark_data['Month'].apply(map_month)
# # Finish the category seasson for the months
# shark_data['Season'] = shark_data['Month'].apply(get_season)

# %%
# # Creats a csv file and saves the data to it
# usa_attack_data.to_csv('USA_Shark.csv', index=False)

# # Code to download it to your system
# #from google.colab import files
# #files.download('USA_Shark.csv')

# %%
# makes a series variable of data for provoked attacks
provoked_data = usa_attack_data[usa_attack_data['Type'] == 'Provoked']
provoked_data_unique = provoked_data.drop_duplicates(subset=['Activity'], keep='first')
provoked_data
# Out:
#                       Date  Year      Type Country        State  \
# 80            19--May-2023  2023  Provoked     USA      Florida
# 85             11-May-2023  2023  Provoked     USA       Hawaii
# 116            01-Jan-2023  2023  Provoked     USA      Florida
# 126            03-Nov-2022  2022  Provoked     USA      Florida
# 130            27-Oct-2022  2022  Provoked     USA  Mississippi
# ...                    ...   ...       ...     ...          ...
# 6524           28-Jul-1873  1873  Provoked     USA     Maryland
# 6538              Aug-1871  1871  Provoked     USA     New York
# 6588  Reported-09-Jul-1863  1863  Provoked     USA       Hawaii
# 6696           06-Jul-1842  1842  Provoked     USA   New Jersey
# 6868        No-date,--1975  1975  Provoked     USA      Florida
#
#                                            Location  \
# 80    Flagship Drive, Summerland Key, Monroe County
# 85                                     Kualoa, Oahu
# 116                          70 miles off Pensacola
# 126                      Cape San Blas, Gulf County
# 130                                     Horn Island
# ...                                             ...
# 6524                                  Chester River
# 6538                                    Long Island
# 6588                                         Palama
# 6696                       Absecon, Atlantic County
# 6868               Riviera Beach, Palm Beach County
#
#                                                Activity  Sex  Age  \
# 80                                              Fishing    M   35
# 85                                        Kayak fishing    M  NaN
# 116                                         Spearishing    M   30
# 126                                             Fishing    M   29
# 130                                             Fishing    M  NaN
# ...                                                 ...  ...  ...
# 6524                                  Fishing (Seining)    M  NaN
# 6538                                      Shark fishing    M  NaN
# 6588                                            Fishing    M  NaN
# 6696                                  Harassing a shark  NaN  NaN
# 6868  Skin diving. Grabbed shark's tail; shark turne...    M   19
#
#                                                  Injury   Time     Month  \
# 80        PROVOKED INCIDENT   Hooked shark bit his foot  20h00       May
# 85                Shark bit kayak, no inury to occupant    NaN       May
# 116       Knocked spear out of his hands and fin bitten  14h50   January
# 126           Right knee & thigh bitten by hooked shark  15h30  November
# 130                                      Minor injuries    NaN   October
# ...                                                 ...    ...       ...
# 6524  Leg severely bitten by netted shark. Lower leg...    NaN      July
# 6538                     Hand injured PROVOKED INCIDENT    NaN    August
# 6588     Hand severed by noosed shark PROVOKED INCIDENT    NaN   Unknown
# 6696              Lacerations to leg  PROVOKED INCIDENT    NaN      July
# 6868  Ankle punctured & lacerated, hands abraded PRO...    NaN   Unknown
#
#        Season
# 80     Spring
# 85     Spring
# 116    Winter
# 126      Fall
# 130      Fall
# ...       ...
# 6524   Summer
# 6538   Summer
# 6588  Unknown
# 6696   Summer
# 6868  Unknown
#
# [233 rows x 13 columns]

# %%
# makes a series variable of data for unprovoked attacks
non_provoked_data = usa_attack_data[usa_attack_data['Type'] != 'Provoked']
non_provoked_data
# Out:
#              Date  Year        Type Country            State  \
# 1     04-Mar-2024  2024  Unprovoked     USA           Hawaii
# 2     02-Mar-2024  2024  Unprovoked     USA           Hawaii
# 10    30-Dec-2023  2023  Unprovoked     USA           Hawaii
# 24    05-Nov-2023  2023  Unprovoked     USA          Florida
# 29    25-Oct-2023  2023  Unprovoked     USA           Hawaii
# ...           ...   ...         ...     ...              ...
# 6891         1958  1958  Unprovoked     USA          Florida
# 6925         1921  1921  Unprovoked     USA          Florida
# 6930  17-Jul-1916  1916  Unprovoked     USA  North Carolina
# 6934   Circa-1862  1862  Unprovoked     USA           Hawaii
# 6941    1900-1905  1900  Unprovoked     USA   North Carolina
#
#                                      Location  Activity Sex  Age  \
# 1                          Old Man's, Waikiki   Surfing   M  NaN
# 2                              Rainbows, Oahu  Swimming   F   11
# 10                           Baby Beach, Maui   Surfing   M   39
# 24              Juno Beach, Palm Beach County  Swimming   M   66
# 29              Pua’ena Point,  Haleiwa, Oahu   Surfing   M   30
# ...                                       ...       ...  ..  ...
# 6891            Palm Beach, Palm Beach County  Standing   M  NaN
# 6925                 Gadsden Point, Tampa Bay   Fishing   M  NaN
# 6930  Somewhere between Hatteras and Beaufort  Swimming   M  NaN
# 6934                                     Puna       NaN   F  NaN
# 6941                           Ocracoke Inlet  Swimming   M  NaN
#
#                                 Injury   Time     Month   Season
# 1       No injury, shark bit surfboard    NaN     March   Spring
# 2             Lacerations to left foot  13h30     March   Spring
# 10                               FATAL  11h12  December   Winter
# 24        Lacerations to right forearm  10h30  November     Fall
# 29                 Bite to right thigh  15h05   October     Fall
# ...                                ...    ...       ...      ...
# 6891  Abrasions & bruises hip to ankle    NaN   Unknown  Unknown
# 6925                2-inch lacerations    NaN   Unknown  Unknown
# 6930                        "Lost leg"    NaN      July   Summer
# 6934                      Ankle bitten    NaN   Unknown  Unknown
# 6941                             FATAL    NaN   Unknown  Unknown
#
# [2305 rows x 13 columns]

# %%
non_provoked_data.head().groupby(['Date','State', 'Location'])['Year'].mean()
# Out:
# Date         State    Location
# 02-Mar-2024  Hawaii   Rainbows, Oahu                   2024.0
# 04-Mar-2024  Hawaii   Old Man's, Waikiki               2024.0
# 05-Nov-2023  Florida  Juno Beach, Palm Beach County    2023.0
# 25-Oct-2023  Hawaii   Pua’ena Point,  Haleiwa, Oahu    2023.0
# 30-Dec-2023  Hawaii   Baby Beach, Maui                 2023.0
# Name: Year, dtype: object

# %%
non_provoked_data.isna().sum()
# Out:
# Date          0
# Year         27
# Type          8
# Country       0
# State         5
# Location     48
# Activity    146
# Sex          88
# Age         694
# Injury        6
# Time        769
# Month         0
# Season        0
# dtype: int64

# %%
non_pro_pivot = non_provoked_data.pivot_table(index='State', columns='Month' , values=['Season'], aggfunc='sum')

pd.set_option('display.max_columns', None) # shows all columns
non_pro_pivot.head()
# Out:
#                  Season                                          \
# Month             April        August December February January
# State
#  New Jersey         NaN           NaN      NaN      NaN     NaN
#  North Carolina     NaN        Summer      NaN      NaN     NaN
# Alabama          Spring  SummerSummer      NaN      NaN     NaN
# Bahamas             NaN           NaN      NaN      NaN     NaN
# CUBA                NaN        Summer      NaN      NaN     NaN
#
#                                                                            \
# Month                                July                      June March
# State
#  New Jersey                           NaN                       NaN   NaN
#  North Carolina                       NaN                       NaN   NaN
# Alabama          SummerSummerSummerSummer  SummerSummerSummerSummer   NaN
# Bahamas                            Summer                       NaN   NaN
# CUBA                                  NaN                       NaN   NaN
#
#
# Month            May November October September                Unknown
# State
#  New Jersey      NaN      NaN     NaN       NaN                Unknown
#  North Carolina  NaN      NaN     NaN       NaN                    NaN
# Alabama          NaN      NaN    Fall      Fall  UnknownUnknownUnknown
# Bahamas          NaN      NaN     NaN       NaN                    NaN
# CUBA             NaN      NaN     NaN       NaN                    NaN

# %%
shark_data
# Out:
#              Date  Year        Type             Country              State  \
# 0     15-Mar-2024  2024  Unprovoked           AUSTRALIA         Queensland
# 1     04-Mar-2024  2024  Unprovoked                 USA             Hawaii
# 2     02-Mar-2024  2024  Unprovoked                 USA             Hawaii
# 3     25-Feb-2024  2024  Unprovoked           AUSTRALIA  Western Australia
# 4     14-Feb-2024  2024  Unprovoked               INDIA        Maharashtra
# ...           ...   ...         ...                 ...                ...
# 6939         1903  1903  Unprovoked           AUSTRALIA  Western Australia
# 6940         1903  1903  Unprovoked           AUSTRALIA  Western Australia
# 6941    1900-1905  1900  Unprovoked                 USA     North Carolina
# 6942    1883-1889  1883  Unprovoked              PANAMA                NaN
# 6943    1845-1853  1845  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 0                           Bargara Beach      Swimming
# 1                      Old Man's, Waikiki       Surfing
# 2                          Rainbows, Oahu      Swimming
# 3              Sandlnd Island, Jurian Bay           NaN
# 4        Vaitarna River, Palghar District       Fishing
# ...                                   ...           ...
# 6939                          Roebuck Bay        Diving
# 6940                                  NaN  Pearl diving
# 6941                       Ocracoke Inlet      Swimming
# 6942                 Panama Bay 8ºN, 79ºW           NaN
# 6943  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex  Age  \
# 0            Brooklyn Sauer   F   13
# 1             Matthew White   M  NaN
# 2                       NaN   F   11
# 3                    female   F   46
# 4       Vicky Suresh Govari   M   32
# ...                     ...  ..  ...
# 6939                   male   M  NaN
# 6940                  Ahmun   M  NaN
# 6941  Coast Guard personnel   M  NaN
# 6942        Jules Patterson   M  NaN
# 6943                   male   M   15
#
#                                                  Injury Unnamed: 11   Time  \
# 0              Minor injuries to back, abdomen and legs         NaN  16h00
# 1                        No injury, shark bit surfboard           N    NaN
# 2                              Lacerations to left foot           N  13h30
# 3                                            Leg bitten           N  11h30
# 4                        Calf of lower left leg injured           N    NaN
# ...                                                 ...         ...    ...
# 6939                                              FATAL           Y    NaN
# 6940                                              FATAL           Y    NaN
# 6941                                              FATAL           Y    NaN
# 6942                                              FATAL           Y    NaN
# 6943  FATAL. "Shark bit him in half, carrying away t...           Y    NaN
#
#             Species                                  Source  \
# 0        Tiger shark                  Yahoo News, 3/15/2024
# 1     Tiger shark 8'                      Surfer, 3/6/2024F
# 2     3' to 4' shark              Hawaii News Now, 3/4/2024
# 3        Tiger shark                    WA Today, 2/26/2024
# 4     Bull shark, 7'              Times of India, 2/14/2024
# ...              ...                                    ...
# 6939             NaN       H. Taunton; N. Bartlett,  p. 234
# 6940             NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6941             NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6942             NaN                    The Sun, 10/20/1938
# 6943             NaN                             S.W. Baker
#
#                                  pdf  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 6939          ND-0005-RoebuckBay.pdf
# 6940               ND-0004-Ahmun.pdf
# 6941  ND-0003-Ocracoke_1900-1905.pdf
# 6942      ND-0002-JulesPatterson.pdf
# 6943              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6939  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6940  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6941  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6942  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6943  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 6939  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0005
# 6940  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0004
# 6941  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0003
# 6942  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0002
# 6943  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0001
#
#      Case Number.1  original order Unnamed: 21 Unnamed: 22     Month   Season
# 0              NaN             NaN         NaN         NaN     March   Spring
# 1              NaN             NaN         NaN         NaN     March   Spring
# 2              NaN             NaN         NaN         NaN     March   Spring
# 3              NaN             NaN         NaN         NaN  February   Winter
# 4              NaN             NaN         NaN         NaN  February   Winter
# ...            ...             ...         ...         ...       ...      ...
# 6939       ND.0005             6.0         NaN         NaN   Unknown  Unknown
# 6940       ND.0004             5.0         NaN         NaN   Unknown  Unknown
# 6941       ND.0003             4.0         NaN         NaN   Unknown  Unknown
# 6942       ND.0002             3.0         NaN         NaN   Unknown  Unknown
# 6943       ND.0001             2.0         NaN         NaN   Unknown  Unknown
#
# [6944 rows x 25 columns]

# %%
us_attacks = non_provoked_data[non_provoked_data['Country'] == 'USA']

# %%
attacks_by_season = us_attacks.groupby('Season').size()
print("Total amount of unprovoked Shark Attacks by Seasons: ")
print(attacks_by_season)
# Out:
# Total amount of unprovoked Shark Attacks by Seasons:
# Season
# Fall       621
# Spring     419
# Summer     907
# Unknown    181
# Winter     177
# dtype: int64

# %%
provoked_data['Age'] = pd.to_numeric(shark_data['Age'], errors='coerce')
# Out:
# <ipython-input-24-57a6f08fe837>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   provoked_data['Age'] = pd.to_numeric(shark_data['Age'], errors='coerce')

# %%
provoked_age = provoked_data.groupby("Sex")['Age'].mean()
provoked_age
# Out:
# Sex
# F    30.181818
# M    30.648148
# Name: Age, dtype: float64

# %%
provoked_age = provoked_data.groupby("Sex")['Age'].median()
provoked_age
# Out:
# Sex
# F    32.0
# M    29.0
# Name: Age, dtype: float64
